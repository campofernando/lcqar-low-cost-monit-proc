# %% [markdown]
# # Prepare visualization of the results

# %% [markdown]
# ## Definitions

# %% [markdown]
# ### Sensors

# %%
sensor_co_name = 'co_all_sensors'
sensor_no2_name = 'no2_all_sensors'
sensor_o3_name = 'o3_all_sensors'
sensor_so2_name = 'so2_all_sensors'
sensor_pm_10_name = 'pm_10_all_sensors'

# %% [markdown]
# ### Directories and paths

# %% [markdown]
# #### R2

# %%
output_directory_path = 'output/'
co_r2_file_name = output_directory_path + sensor_co_name + '_r2.csv'
no2_r2_file_name = output_directory_path + sensor_no2_name + '_r2.csv'
o3_r2_file_name = output_directory_path + sensor_o3_name + '_r2.csv'
so2_r2_file_name = output_directory_path + sensor_so2_name + '_r2.csv'
pm_10_r2_file_name = output_directory_path + sensor_pm_10_name + '_r2.csv'

# %% [markdown]
# #### RMSE

# %%
output_directory_path = 'output/'
co_rmse_file_name = output_directory_path + sensor_co_name + '_rmse.csv'
no2_rmse_file_name = output_directory_path + sensor_no2_name + '_rmse.csv'
o3_rmse_file_name = output_directory_path + sensor_o3_name + '_rmse.csv'
so2_rmse_file_name = output_directory_path + sensor_so2_name + '_rmse.csv'
pm_10_rmse_file_name = output_directory_path + sensor_pm_10_name + '_rmse.csv'

# %% [markdown]
# #### MAE

# %%
output_directory_path = 'output/'
co_mae_file_name = output_directory_path + sensor_co_name + '_mae.csv'
no2_mae_file_name = output_directory_path + sensor_no2_name + '_mae.csv'
o3_mae_file_name = output_directory_path + sensor_o3_name + '_mae.csv'
so2_mae_file_name = output_directory_path + sensor_so2_name + '_mae.csv'
pm_10_mae_file_name = output_directory_path + sensor_pm_10_name + '_mae.csv'

# %% [markdown]
# ## Upload Results

# %%
def rename_sensors_names(old_names):
    names = [name.strip() for name in old_names.split(',')]
    new_names = ""
    for name in names:
        if 'measuring' in name: 
            if len(new_names) > 0: new_names += " + "
            new_name = name.replace('measuring ', '')
            new_names += new_name
        elif name == 'temperature': 
            if len(new_names) > 0: new_names += " + "
            new_names += 'T'
    return new_names

# %% [markdown]
# ### CO

# %% [markdown]
# #### R2

# %%
import pandas as pd

co_r2_dataframe = (pd.read_csv(co_r2_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
co_r2_dataframe = co_r2_dataframe[~(co_r2_dataframe['Sensores'].str.contains("no Temp"))]
co_r2_dataframe['Sensores'] = (co_r2_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
co_r2_dataframe
# Out:
#                                               Sensores  \
# 0                                                   CO
# 1                                             CO + NO2
# 2                                            CO + O3 1
# 3                                            CO + O3 2
# 4                                           CO + SO2 1
# ..                                                 ...
# 123          CO + NO2 + O3 1 + O3 2 + SO2 2 + PM10 + T
# 124         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 125         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 126        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 127  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -0.3141009361973328, 'Std': 0.3749497...
# 1    {'Mean': -0.40451333734240186, 'Std': 0.289843...
# 2    {'Mean': -0.4879310398805421, 'Std': 0.4997529...
# 3    {'Mean': -0.5173165166545248, 'Std': 0.6732253...
# ...

# %% [markdown]
# #### RMSE

# %%
co_rmse_dataframe = (pd.read_csv(co_rmse_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
co_rmse_dataframe = co_rmse_dataframe[~(co_rmse_dataframe['Sensores'].str.contains("no Temp"))]
co_rmse_dataframe['Sensores'] = (co_rmse_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
co_rmse_dataframe
# Out:
#                                               Sensores  \
# 0                                                   CO
# 1                                             CO + NO2
# 2                                            CO + O3 1
# 3                                            CO + O3 2
# 4                                           CO + SO2 1
# ..                                                 ...
# 123          CO + NO2 + O3 1 + O3 2 + SO2 2 + PM10 + T
# 124         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 125         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 126        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 127  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -0.06012620415003476, 'Std': 0.012085...
# 1    {'Mean': -0.06290576486047667, 'Std': 0.013627...
# 2    {'Mean': -0.06360727789154567, 'Std': 0.012341...
# 3    {'Mean': -0.06359330387807346, 'Std': 0.014255...
# ...

# %% [markdown]
# #### MAE

# %%
co_mae_dataframe = (pd.read_csv(co_mae_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
co_mae_dataframe = co_mae_dataframe[~(co_mae_dataframe['Sensores'].str.contains("no Temp"))]
co_mae_dataframe['Sensores'] = (co_mae_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
co_mae_dataframe
# Out:
#                                               Sensores  \
# 0                                                   CO
# 1                                             CO + NO2
# 2                                            CO + O3 1
# 3                                            CO + O3 2
# 4                                           CO + SO2 1
# ..                                                 ...
# 123          CO + NO2 + O3 1 + O3 2 + SO2 2 + PM10 + T
# 124         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 125         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 126        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 127  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -0.045359138096482496, 'Std': 0.00902...
# 1    {'Mean': -0.04773095434410442, 'Std': 0.008979...
# 2    {'Mean': -0.048555073809205804, 'Std': 0.00894...
# 3    {'Mean': -0.04818710364133294, 'Std': 0.011695...
# ...

# %% [markdown]
# ### NO2

# %% [markdown]
# #### R2

# %%
import pandas as pd

no2_r2_dataframe = (pd.read_csv(no2_r2_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
no2_r2_dataframe = no2_r2_dataframe[~(no2_r2_dataframe['Sensores'].str.contains("no Temp"))]
no2_r2_dataframe['Sensores'] = (no2_r2_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
no2_r2_dataframe
# Out:
#                                               Sensores  \
# 0                                                  NO2
# 1                                             CO + NO2
# 2                                           NO2 + O3 1
# 3                                           NO2 + O3 2
# 4                                          NO2 + SO2 1
# ..                                                 ...
# 123          CO + NO2 + O3 1 + O3 2 + SO2 2 + PM10 + T
# 124         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 125         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 126       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 127  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -0.600592864478784, 'Std': 0.73182035...
# 1    {'Mean': -0.5676205156193254, 'Std': 0.7665661...
# 2    {'Mean': -0.5608531995543466, 'Std': 0.6772017...
# 3    {'Mean': -0.8479069964553508, 'Std': 1.0591280...
# ...

# %% [markdown]
# #### RMSE

# %%
no2_rmse_dataframe = (pd.read_csv(no2_rmse_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
no2_rmse_dataframe = no2_rmse_dataframe[~(no2_rmse_dataframe['Sensores'].str.contains("no Temp"))]
no2_rmse_dataframe['Sensores'] = (no2_rmse_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
no2_rmse_dataframe
# Out:
#                                               Sensores  \
# 0                                                  NO2
# 1                                             CO + NO2
# 2                                           NO2 + O3 1
# 3                                           NO2 + O3 2
# 4                                          NO2 + SO2 1
# ..                                                 ...
# 123          CO + NO2 + O3 1 + O3 2 + SO2 2 + PM10 + T
# 124         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 125         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 126       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 127  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -10.052049109450161, 'Std': 3.0682057...
# 1    {'Mean': -9.869182140345062, 'Std': 2.98046882...
# 2    {'Mean': -9.886916713894594, 'Std': 2.79634168...
# 3    {'Mean': -10.400128335341705, 'Std': 2.5287212...
# ...

# %% [markdown]
# #### MAE

# %%
no2_mae_dataframe = (pd.read_csv(no2_mae_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
no2_mae_dataframe = no2_mae_dataframe[~(no2_mae_dataframe['Sensores'].str.contains("no Temp"))]
no2_mae_dataframe['Sensores'] = (no2_mae_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
no2_mae_dataframe
# Out:
#                                               Sensores  \
# 0                                                  NO2
# 1                                             CO + NO2
# 2                                           NO2 + O3 1
# 3                                           NO2 + O3 2
# 4                                          NO2 + SO2 1
# ..                                                 ...
# 123          CO + NO2 + O3 1 + O3 2 + SO2 2 + PM10 + T
# 124         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 125         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 126       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 127  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -7.349040201948938, 'Std': 1.68862001...
# 1    {'Mean': -7.409667486368015, 'Std': 1.71229064...
# 2    {'Mean': -7.3175187372805555, 'Std': 1.5941332...
# 3    {'Mean': -7.713786942954829, 'Std': 1.47559714...
# ...

# %% [markdown]
# ### O3

# %% [markdown]
# #### R2

# %%
import pandas as pd

o3_r2_dataframe = (pd.read_csv(o3_r2_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
o3_r2_dataframe = o3_r2_dataframe[~(o3_r2_dataframe['Sensores'].str.contains("no Temp"))]
o3_r2_dataframe['Sensores'] = (o3_r2_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
o3_r2_dataframe
# Out:
#                                               Sensores  \
# 0                                                 O3 1
# 1                                                 O3 2
# 2                                            CO + O3 1
# 3                                            CO + O3 2
# 4                                           NO2 + O3 1
# ..                                                 ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -0.5491688570586055, 'Std': 0.4610045...
# 1    {'Mean': -0.18684094577788493, 'Std': 0.676320...
# 2    {'Mean': -2.6338058007630227, 'Std': 2.5024735...
# 3    {'Mean': -2.1507644953048564, 'Std': 3.5964719...
# ...

# %% [markdown]
# #### RMSE

# %%
o3_rmse_dataframe = (pd.read_csv(o3_rmse_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
o3_rmse_dataframe = o3_rmse_dataframe[~(o3_rmse_dataframe['Sensores'].str.contains("no Temp"))]
o3_rmse_dataframe['Sensores'] = (o3_rmse_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
o3_rmse_dataframe
# Out:
#                                               Sensores  \
# 0                                                 O3 1
# 1                                                 O3 2
# 2                                            CO + O3 1
# 3                                            CO + O3 2
# 4                                           NO2 + O3 1
# ..                                                 ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -16.722452571685267, 'Std': 4.4604639...
# 1    {'Mean': -13.769332656688935, 'Std': 2.4474715...
# 2    {'Mean': -25.511642327302496, 'Std': 14.517904...
# 3    {'Mean': -18.80169592164388, 'Std': 5.40273246...
# ...

# %% [markdown]
# #### MAE

# %%
o3_mae_dataframe = (pd.read_csv(o3_mae_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
o3_mae_dataframe = o3_mae_dataframe[~(o3_mae_dataframe['Sensores'].str.contains("no Temp"))]
o3_mae_dataframe['Sensores'] = (o3_mae_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
o3_mae_dataframe
# Out:
#                                               Sensores  \
# 0                                                 O3 1
# 1                                                 O3 2
# 2                                            CO + O3 1
# 3                                            CO + O3 2
# 4                                           NO2 + O3 1
# ..                                                 ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -13.339679054855551, 'Std': 2.9549604...
# 1    {'Mean': -11.013743011289373, 'Std': 2.0951340...
# 2    {'Mean': -16.472239104169176, 'Std': 4.8490097...
# 3    {'Mean': -14.2612347295378, 'Std': 4.506884953...
# ...

# %% [markdown]
# ### SO2

# %% [markdown]
# #### R2

# %%
import pandas as pd

so2_r2_dataframe = (pd.read_csv(so2_r2_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
so2_r2_dataframe = so2_r2_dataframe[~(so2_r2_dataframe['Sensores'].str.contains("no Temp"))]
so2_r2_dataframe['Sensores'] = (so2_r2_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
so2_r2_dataframe
# Out:
#                                               Sensores  \
# 0                                                SO2 1
# 1                                                SO2 2
# 2                                           CO + SO2 1
# 3                                           CO + SO2 2
# 4                                          NO2 + SO2 1
# ..                                                 ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -0.13479849438233046, 'Std': 0.219267...
# 1    {'Mean': -0.09521050429014803, 'Std': 0.152881...
# 2    {'Mean': -0.10186390799942782, 'Std': 0.235537...
# 3    {'Mean': -0.2388222626459527, 'Std': 0.4331330...
# ...

# %% [markdown]
# #### RMSE

# %%
so2_rmse_dataframe = (pd.read_csv(so2_rmse_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
so2_rmse_dataframe = so2_rmse_dataframe[~(so2_rmse_dataframe['Sensores'].str.contains("no Temp"))]
so2_rmse_dataframe['Sensores'] = (so2_rmse_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
so2_rmse_dataframe
# Out:
#                                               Sensores  \
# 0                                                SO2 1
# 1                                                SO2 2
# 2                                           CO + SO2 1
# 3                                           CO + SO2 2
# 4                                          NO2 + SO2 1
# ..                                                 ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -17.982649977312875, 'Std': 8.4241715...
# 1    {'Mean': -17.816887115266926, 'Std': 8.5119714...
# 2    {'Mean': -17.63382069931629, 'Std': 8.18983563...
# 3    {'Mean': -18.27663338732657, 'Std': 8.10250745...
# ...

# %% [markdown]
# #### MAE

# %%
so2_mae_dataframe = (pd.read_csv(so2_mae_file_name)
                .rename(columns={'Unnamed: 0': 'Sensores',
                                 'MLP Regression': 'MLP',
                                 'Multilinear Regression': 'MLR',
                                 'KNN Regression': 'KNN',
                                 'Random Forests Regression': 'RF'}))
so2_mae_dataframe = so2_mae_dataframe[~(so2_mae_dataframe['Sensores'].str.contains("no Temp"))]
so2_mae_dataframe['Sensores'] = (so2_mae_dataframe['Sensores']
                            .apply(lambda names: rename_sensors_names(old_names=names)))
so2_mae_dataframe
# Out:
#                                               Sensores  \
# 0                                                SO2 1
# 1                                                SO2 2
# 2                                           CO + SO2 1
# 3                                           CO + SO2 2
# 4                                          NO2 + SO2 1
# ..                                                 ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T
#
#                                                    MLP  \
# 0    {'Mean': -8.874295043551312, 'Std': 2.64188055...
# 1    {'Mean': -8.732906643064767, 'Std': 2.85840915...
# 2    {'Mean': -8.48426532312914, 'Std': 2.170377327...
# 3    {'Mean': -9.260818664245821, 'Std': 2.67423532...
# ...

# %% [markdown]
# ## Performance metrics

# %% [markdown]
# ### R2

# %% [markdown]
# #### CO

# %%
import ast

r2_dataframe = pd.DataFrame(columns=['Sensores', 'MLP', 'MLR', 'KNN', 'RF'])
r2_original_dataframe = co_r2_dataframe
r2_original_dataframe = r2_original_dataframe.reset_index().drop(columns='index')
r2_dataframe['Sensores'] = r2_original_dataframe['Sensores']
mean_r2_dataframe = r2_dataframe.copy()
mask_dataframe = r2_dataframe.copy()
for index, row in r2_original_dataframe.iterrows():
    row_MLP = ast.literal_eval(row['MLP'])
    row_MLR = ast.literal_eval(row['MLR'])
    row_KNN = ast.literal_eval(row['KNN'])
    row_RF = ast.literal_eval(row['RF'])
    r2_dataframe.loc[index, 'MLP'] = f"{round(row_MLP['Mean'], 2)} ± {round(row_MLP['Std'], 2)}"
    r2_dataframe.loc[index, 'MLR'] = f"{round(row_MLR['Mean'], 2)} ± {round(row_MLR['Std'], 2)}"
    r2_dataframe.loc[index, 'KNN'] = f"{round(row_KNN['Mean'], 2)} ± {round(row_KNN['Std'], 2)}"
    r2_dataframe.loc[index, 'RF'] = f"{round(row_RF['Mean'], 2)} ± {round(row_RF['Std'], 2)}"
    mean_r2_dataframe.loc[index, 'MLP'] = round(row_MLP['Mean'], 2)
    mean_r2_dataframe.loc[index, 'MLR'] = round(row_MLR['Mean'], 2)
    mean_r2_dataframe.loc[index, 'KNN'] = round(row_KNN['Mean'], 2)
    mean_r2_dataframe.loc[index, 'RF'] = round(row_RF['Mean'], 2)

r2_dataframe.to_csv(output_directory_path + sensor_o3_name + "_r2_formated_results.csv")
r2_dataframe
# Out:
#                                               Sensores             MLP  \
# 0                                                   CO    -0.31 ± 0.37
# 1                                             CO + NO2     -0.4 ± 0.29
# 2                                            CO + O3 1     -0.49 ± 0.5
# 3                                            CO + O3 2    -0.52 ± 0.67
# 4                                           CO + SO2 1    -0.57 ± 0.63
# ..                                                 ...             ...
# 123          CO + NO2 + O3 1 + O3 2 + SO2 2 + PM10 + T  -11.06 ± 13.13
# 124         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T  -75.96 ± 59.26
# 125         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -35.76 ± 52.33
# 126        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -51.21 ± 34.89
# 127  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -91.54 ± 52.59
#
#               MLR           KNN            RF
# 0    -0.31 ± 0.37  -0.67 ± 0.61  -0.28 ± 0.31
# ...

# %%
mean_r2_dataframe
positive_r2_mlp = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -1]['MLP']
positive_r2_mlr = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -1]['MLR']
positive_r2_knn = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -1]['KNN']
positive_r2_rf = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -1]['RF']

positive_r2_dataframe = pd.concat([positive_r2_mlp, positive_r2_mlr, positive_r2_knn, positive_r2_rf], axis=1)
positive_r2_dataframe['Sensores'] = mean_r2_dataframe.loc[positive_r2_dataframe.index, 'Sensores']
positive_r2_dataframe.head(9)
# Out:
#     MLP   MLR   KNN    RF         Sensores
# 0 -0.31 -0.31 -0.67 -0.28               CO
# 1  -0.4 -0.33 -0.32 -0.25         CO + NO2
# 2 -0.49 -0.35 -0.55 -0.24        CO + O3 1
# 3 -0.52 -0.31 -0.77 -0.32        CO + O3 2
# 4 -0.57 -0.32 -0.42  -0.3       CO + SO2 1
# 5 -0.63 -0.38  -0.6 -0.32       CO + SO2 2
# 6 -0.36 -0.32 -0.55 -0.29        CO + PM10
# 7 -0.49 -0.33 -0.65 -0.32           CO + T
# 9 -0.43 -0.33 -0.69 -0.29  CO + NO2 + O3 2

# %%
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(positive_r2_dataframe['Sensores']))
plt.figure(figsize=(10,20))

ax_r2  = plt.axes()
ax_r2.scatter(positive_r2_dataframe['MLP'], y_pos)
ax_r2.scatter(positive_r2_dataframe['MLR'], y_pos)
ax_r2.scatter(positive_r2_dataframe['KNN'], y_pos)
ax_r2.scatter(positive_r2_dataframe['RF'], y_pos)
ax_r2.yaxis.grid(True, linestyle='--', color='gray', alpha=0.5)
ax_r2.set_yticks(y_pos, labels=positive_r2_dataframe['Sensores'])
ax_r2.invert_yaxis()  # labels read top-to-bottom

for i, value in enumerate(positive_r2_dataframe['MLP']):
    if not np.isnan(value):
        ax_r2.text(value, i, 'MLP', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['MLR']):
    if not np.isnan(value):
        ax_r2.text(value, i, 'MLR', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['KNN']):
    if not np.isnan(value):
        ax_r2.text(value, y_pos[i], 'KNN', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['RF']):
    if not np.isnan(value):
        ax_r2.text(value, y_pos[i], 'RF', fontsize=10, ha='right', va='bottom')

for i, sensor_index in enumerate(positive_r2_dataframe.index):
    values = list(positive_r2_dataframe.drop(columns='Sensores').iloc[i])
    for j, value in enumerate(values):
        if j < len(values) - 1 and not np.isnan(value) and not np.isnan(values[j + 1]):
            point_a = (value, i)
            point_b = (values[j + 1], i)
            ax_r2.plot([point_a[0], point_b[0]], [point_a[1], point_b[1]], color='black', linestyle='-')


plt.show()

# %% [markdown]
# #### NO2

# %%
import ast

r2_dataframe = pd.DataFrame(columns=['Sensores', 'MLP', 'MLR', 'KNN', 'RF'])
r2_original_dataframe = no2_r2_dataframe
r2_original_dataframe = r2_original_dataframe.reset_index().drop(columns='index')
r2_dataframe['Sensores'] = r2_original_dataframe['Sensores']
mean_r2_dataframe = r2_dataframe.copy()
mask_dataframe = r2_dataframe.copy()
for index, row in r2_original_dataframe.iterrows():
    row_MLP = ast.literal_eval(row['MLP'])
    row_MLR = ast.literal_eval(row['MLR'])
    row_KNN = ast.literal_eval(row['KNN'])
    row_RF = ast.literal_eval(row['RF'])
    r2_dataframe.loc[index, 'MLP'] = f"{round(row_MLP['Mean'], 2)} ± {round(row_MLP['Std'], 2)}"
    r2_dataframe.loc[index, 'MLR'] = f"{round(row_MLR['Mean'], 2)} ± {round(row_MLR['Std'], 2)}"
    r2_dataframe.loc[index, 'KNN'] = f"{round(row_KNN['Mean'], 2)} ± {round(row_KNN['Std'], 2)}"
    r2_dataframe.loc[index, 'RF'] = f"{round(row_RF['Mean'], 2)} ± {round(row_RF['Std'], 2)}"
    mean_r2_dataframe.loc[index, 'MLP'] = round(row_MLP['Mean'], 2)
    mean_r2_dataframe.loc[index, 'MLR'] = round(row_MLR['Mean'], 2)
    mean_r2_dataframe.loc[index, 'KNN'] = round(row_KNN['Mean'], 2)
    mean_r2_dataframe.loc[index, 'RF'] = round(row_RF['Mean'], 2)

r2_dataframe.to_csv(output_directory_path + sensor_o3_name + "_r2_formated_results.csv")
r2_dataframe
# Out:
#                                               Sensores           MLP  \
# 0                                                  NO2   -0.6 ± 0.73
# 1                                             CO + NO2  -0.57 ± 0.77
# 2                                           NO2 + O3 1  -0.56 ± 0.68
# 3                                           NO2 + O3 2  -0.85 ± 1.06
# 4                                          NO2 + SO2 1  -1.32 ± 1.22
# ..                                                 ...           ...
# 123          CO + NO2 + O3 1 + O3 2 + SO2 2 + PM10 + T  -1.13 ± 1.45
# 124         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T   -1.4 ± 1.58
# 125         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -1.44 ± 1.58
# 126       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T   -1.47 ± 1.6
# 127  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T   -1.5 ± 1.92
#
#               MLR           KNN            RF
# 0    -0.58 ± 0.75  -0.73 ± 0.72   -0.6 ± 0.73
# ...

# %%
mean_r2_dataframe
positive_r2_mlp = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -1]['MLP']
positive_r2_mlr = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -1]['MLR']
positive_r2_knn = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -1]['KNN']
positive_r2_rf = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -1]['RF']

positive_r2_dataframe = pd.concat([positive_r2_mlp, positive_r2_mlr, positive_r2_knn, positive_r2_rf], axis=1)
positive_r2_dataframe['Sensores'] = mean_r2_dataframe.loc[positive_r2_dataframe.index, 'Sensores']
positive_r2_dataframe.head(9)
# Out:
#     MLP   MLR   KNN    RF         Sensores
# 0  -0.6 -0.58 -0.73  -0.6              NO2
# 1 -0.57 -0.43 -0.61 -0.45         CO + NO2
# 2 -0.56 -0.55 -0.81 -0.61       NO2 + O3 1
# 3 -0.85 -0.62 -1.26 -0.65       NO2 + O3 2
# 5 -0.74 -0.64 -1.72 -0.77      NO2 + SO2 2
# 6 -0.58 -0.57 -0.87 -0.63       NO2 + PM10
# 7 -0.81 -0.58 -1.03 -0.68          NO2 + T
# 8 -0.49 -0.47 -0.71 -0.46  CO + NO2 + O3 1
# 9 -0.98 -0.47 -1.23 -0.45  CO + NO2 + O3 2

# %%
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(positive_r2_dataframe['Sensores']))
plt.figure(figsize=(10,20))

ax_r2  = plt.axes()
ax_r2.scatter(positive_r2_dataframe['MLP'], y_pos)
ax_r2.scatter(positive_r2_dataframe['MLR'], y_pos)
ax_r2.scatter(positive_r2_dataframe['KNN'], y_pos)
ax_r2.scatter(positive_r2_dataframe['RF'], y_pos)
ax_r2.yaxis.grid(True, linestyle='--', color='gray', alpha=0.5)
ax_r2.set_yticks(y_pos, labels=positive_r2_dataframe['Sensores'])
ax_r2.invert_yaxis()  # labels read top-to-bottom

for i, value in enumerate(positive_r2_dataframe['MLP']):
    if not np.isnan(value):
        ax_r2.text(value, i, 'MLP', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['MLR']):
    if not np.isnan(value):
        ax_r2.text(value, i, 'MLR', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['KNN']):
    if not np.isnan(value):
        ax_r2.text(value, y_pos[i], 'KNN', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['RF']):
    if not np.isnan(value):
        ax_r2.text(value, y_pos[i], 'RF', fontsize=10, ha='right', va='bottom')

for i, sensor_index in enumerate(positive_r2_dataframe.index):
    values = list(positive_r2_dataframe.drop(columns='Sensores').iloc[i])
    for j, value in enumerate(values):
        if j < len(values) - 1 and not np.isnan(value) and not np.isnan(values[j + 1]):
            point_a = (value, i)
            point_b = (values[j + 1], i)
            ax_r2.plot([point_a[0], point_b[0]], [point_a[1], point_b[1]], color='black', linestyle='-')


plt.show()

# %% [markdown]
# #### O3

# %%
import ast

r2_dataframe = pd.DataFrame(columns=['Sensores', 'MLP', 'MLR', 'KNN', 'RF'])
# r2_original_dataframe = pd.concat([co_r2_dataframe, no2_r2_dataframe, o3_r2_dataframe, so2_r2_dataframe], axis=0)
r2_original_dataframe = o3_r2_dataframe
r2_original_dataframe = r2_original_dataframe.reset_index().drop(columns='index')
r2_dataframe['Sensores'] = r2_original_dataframe['Sensores']
mean_r2_dataframe = r2_dataframe.copy()
mask_dataframe = r2_dataframe.copy()
for index, row in r2_original_dataframe.iterrows():
    row_MLP = ast.literal_eval(row['MLP'])
    row_MLR = ast.literal_eval(row['MLR'])
    row_KNN = ast.literal_eval(row['KNN'])
    row_RF = ast.literal_eval(row['RF'])
    r2_dataframe.loc[index, 'MLP'] = f"{round(row_MLP['Mean'], 2)} ± {round(row_MLP['Std'], 2)}"
    r2_dataframe.loc[index, 'MLR'] = f"{round(row_MLR['Mean'], 2)} ± {round(row_MLR['Std'], 2)}"
    r2_dataframe.loc[index, 'KNN'] = f"{round(row_KNN['Mean'], 2)} ± {round(row_KNN['Std'], 2)}"
    r2_dataframe.loc[index, 'RF'] = f"{round(row_RF['Mean'], 2)} ± {round(row_RF['Std'], 2)}"
    mean_r2_dataframe.loc[index, 'MLP'] = round(row_MLP['Mean'], 2)
    mean_r2_dataframe.loc[index, 'MLR'] = round(row_MLR['Mean'], 2)
    mean_r2_dataframe.loc[index, 'KNN'] = round(row_KNN['Mean'], 2)
    mean_r2_dataframe.loc[index, 'RF'] = round(row_RF['Mean'], 2)

r2_dataframe.to_csv(output_directory_path + sensor_o3_name + "_r2_formated_results.csv")
r2_dataframe
# Out:
#                                               Sensores             MLP  \
# 0                                                 O3 1    -0.55 ± 0.46
# 1                                                 O3 2    -0.19 ± 0.68
# 2                                            CO + O3 1     -2.63 ± 2.5
# 3                                            CO + O3 2     -2.15 ± 3.6
# 4                                           NO2 + O3 1     -0.7 ± 0.56
# ..                                                 ...             ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T   -22.5 ± 41.23
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T    -6.27 ± 8.75
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T    -6.33 ± 5.95
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T    -5.69 ± 5.33
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -10.18 ± 15.97
#
#               MLR           KNN            RF
# 0    -0.42 ± 0.34   -0.5 ± 0.41  -0.71 ± 0.44
# ...

# %%
mean_r2_dataframe
positive_r2_mlp = mean_r2_dataframe[mean_r2_dataframe['MLP'] > 0.15]['MLP']
positive_r2_mlr = mean_r2_dataframe[mean_r2_dataframe['MLR'] > 0.15]['MLR']
positive_r2_knn = mean_r2_dataframe[mean_r2_dataframe['KNN'] > 0.15]['KNN']
positive_r2_rf = mean_r2_dataframe[mean_r2_dataframe['RF'] > 0.15]['RF']

positive_r2_dataframe = pd.concat([positive_r2_mlp, positive_r2_mlr, positive_r2_knn, positive_r2_rf], axis=1)
positive_r2_dataframe['Sensores'] = mean_r2_dataframe.loc[positive_r2_dataframe.index, 'Sensores']
positive_r2_dataframe.head(9)
# Out:
#      MLP   MLR  KNN    RF               Sensores
# 10  0.17   NaN  NaN   NaN               O3 1 + T
# 21   NaN  0.26  NaN   NaN          CO + O3 1 + T
# 25   NaN  0.16  NaN   NaN          CO + O3 2 + T
# 43   NaN  0.18  NaN   NaN       O3 1 + SO2 2 + T
# 55   NaN  0.26  NaN   NaN    CO + NO2 + O3 1 + T
# 59   NaN  0.16  NaN   NaN    CO + NO2 + O3 2 + T
# 63   NaN  0.25  NaN   NaN   CO + O3 1 + O3 2 + T
# 66   NaN  0.27  NaN   NaN  CO + O3 1 + SO2 1 + T
# 68   NaN   0.3  NaN  0.17  CO + O3 1 + SO2 2 + T

# %%
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(positive_r2_dataframe['Sensores']))
plt.figure(figsize=(10,20))

ax_r2  = plt.axes()
ax_r2.scatter(positive_r2_dataframe['MLP'], y_pos)
ax_r2.scatter(positive_r2_dataframe['MLR'], y_pos)
ax_r2.scatter(positive_r2_dataframe['KNN'], y_pos)
ax_r2.scatter(positive_r2_dataframe['RF'], y_pos)
ax_r2.yaxis.grid(True, linestyle='--', color='gray', alpha=0.5)
ax_r2.set_yticks(y_pos, labels=positive_r2_dataframe['Sensores'])
ax_r2.invert_yaxis()  # labels read top-to-bottom

for i, value in enumerate(positive_r2_dataframe['MLP']):
    if not np.isnan(value):
        ax_r2.text(value, i, 'MLP', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['MLR']):
    if not np.isnan(value):
        ax_r2.text(value, i, 'MLR', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['KNN']):
    if not np.isnan(value):
        ax_r2.text(value, y_pos[i], 'KNN', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['RF']):
    if not np.isnan(value):
        ax_r2.text(value, y_pos[i], 'RF', fontsize=10, ha='right', va='bottom')

for i, sensor_index in enumerate(positive_r2_dataframe.index):
    values = list(positive_r2_dataframe.drop(columns='Sensores').iloc[i])
    for j, value in enumerate(values):
        if j < len(values) - 1 and not np.isnan(value) and not np.isnan(values[j + 1]):
            point_a = (value, i)
            point_b = (values[j + 1], i)
            ax_r2.plot([point_a[0], point_b[0]], [point_a[1], point_b[1]], color='black', linestyle='-')


plt.show()

# %% [markdown]
# #### SO2

# %%
import ast

r2_dataframe = pd.DataFrame(columns=['Sensores', 'MLP', 'MLR', 'KNN', 'RF'])
r2_original_dataframe = so2_r2_dataframe
r2_original_dataframe = r2_original_dataframe.reset_index().drop(columns='index')
r2_dataframe['Sensores'] = r2_original_dataframe['Sensores']
mean_r2_dataframe = r2_dataframe.copy()
mask_dataframe = r2_dataframe.copy()
for index, row in r2_original_dataframe.iterrows():
    row_MLP = ast.literal_eval(row['MLP'])
    row_MLR = ast.literal_eval(row['MLR'])
    row_KNN = ast.literal_eval(row['KNN'])
    row_RF = ast.literal_eval(row['RF'])
    r2_dataframe.loc[index, 'MLP'] = f"{round(row_MLP['Mean'], 2)} ± {round(row_MLP['Std'], 2)}"
    r2_dataframe.loc[index, 'MLR'] = f"{round(row_MLR['Mean'], 2)} ± {round(row_MLR['Std'], 2)}"
    r2_dataframe.loc[index, 'KNN'] = f"{round(row_KNN['Mean'], 2)} ± {round(row_KNN['Std'], 2)}"
    r2_dataframe.loc[index, 'RF'] = f"{round(row_RF['Mean'], 2)} ± {round(row_RF['Std'], 2)}"
    mean_r2_dataframe.loc[index, 'MLP'] = round(row_MLP['Mean'], 2)
    mean_r2_dataframe.loc[index, 'MLR'] = round(row_MLR['Mean'], 2)
    mean_r2_dataframe.loc[index, 'KNN'] = round(row_KNN['Mean'], 2)
    mean_r2_dataframe.loc[index, 'RF'] = round(row_RF['Mean'], 2)

r2_dataframe.to_csv(output_directory_path + sensor_o3_name + "_r2_formated_results.csv")
r2_dataframe
# Out:
#                                               Sensores           MLP  \
# 0                                                SO2 1  -0.13 ± 0.22
# 1                                                SO2 2   -0.1 ± 0.15
# 2                                           CO + SO2 1   -0.1 ± 0.24
# 3                                           CO + SO2 2  -0.24 ± 0.43
# 4                                          NO2 + SO2 1  -0.34 ± 0.54
# ..                                                 ...           ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T   -0.74 ± 0.9
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -0.61 ± 0.65
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -0.77 ± 0.97
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -1.07 ± 1.13
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -0.89 ± 0.93
#
#               MLR           KNN            RF
# 0    -0.13 ± 0.22  -0.37 ± 0.36  -0.23 ± 0.36
# ...

# %%
mean_r2_dataframe
positive_r2_mlp = mean_r2_dataframe[mean_r2_dataframe['MLP'] > -0.5]['MLP']
positive_r2_mlr = mean_r2_dataframe[mean_r2_dataframe['MLR'] > -0.5]['MLR']
positive_r2_knn = mean_r2_dataframe[mean_r2_dataframe['KNN'] > -0.5]['KNN']
positive_r2_rf = mean_r2_dataframe[mean_r2_dataframe['RF'] > -0.5]['RF']

positive_r2_dataframe = pd.concat([positive_r2_mlp, positive_r2_mlr, positive_r2_knn, positive_r2_rf], axis=1)
positive_r2_dataframe['Sensores'] = mean_r2_dataframe.loc[positive_r2_dataframe.index, 'Sensores']
positive_r2_dataframe.head(9)
# Out:
#      MLP   MLR   KNN    RF      Sensores
# 0  -0.13 -0.13 -0.37 -0.23         SO2 1
# 1   -0.1 -0.16   NaN -0.29         SO2 2
# 2   -0.1 -0.13   NaN -0.02    CO + SO2 1
# 3  -0.24 -0.14   NaN -0.12    CO + SO2 2
# 4  -0.34 -0.14 -0.41 -0.18   NO2 + SO2 1
# 5  -0.27 -0.17   NaN -0.36   NO2 + SO2 2
# 6   -0.1 -0.14 -0.47  -0.1  O3 1 + SO2 1
# 9  -0.26  -0.2   NaN -0.34  O3 2 + SO2 2
# 11 -0.14 -0.13   NaN  -0.2  SO2 1 + PM10

# %%
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(positive_r2_dataframe['Sensores']))
plt.figure(figsize=(10,20))

ax_r2  = plt.axes()
ax_r2.scatter(positive_r2_dataframe['MLP'], y_pos)
ax_r2.scatter(positive_r2_dataframe['MLR'], y_pos)
ax_r2.scatter(positive_r2_dataframe['KNN'], y_pos)
ax_r2.scatter(positive_r2_dataframe['RF'], y_pos)
ax_r2.yaxis.grid(True, linestyle='--', color='gray', alpha=0.5)
ax_r2.set_yticks(y_pos, labels=positive_r2_dataframe['Sensores'])
ax_r2.invert_yaxis()  # labels read top-to-bottom

for i, value in enumerate(positive_r2_dataframe['MLP']):
    if not np.isnan(value):
        ax_r2.text(value, i, 'MLP', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['MLR']):
    if not np.isnan(value):
        ax_r2.text(value, i, 'MLR', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['KNN']):
    if not np.isnan(value):
        ax_r2.text(value, y_pos[i], 'KNN', fontsize=10, ha='right', va='bottom')

for i, value in enumerate(positive_r2_dataframe['RF']):
    if not np.isnan(value):
        ax_r2.text(value, y_pos[i], 'RF', fontsize=10, ha='right', va='bottom')

for i, sensor_index in enumerate(positive_r2_dataframe.index):
    values = list(positive_r2_dataframe.drop(columns='Sensores').iloc[i])
    for j, value in enumerate(values):
        if j < len(values) - 1 and not np.isnan(value) and not np.isnan(values[j + 1]):
            point_a = (value, i)
            point_b = (values[j + 1], i)
            ax_r2.plot([point_a[0], point_b[0]], [point_a[1], point_b[1]], color='black', linestyle='-')


plt.show()

# %% [markdown]
# ### RMSE

# %%
import ast

rmse_dataframe = pd.DataFrame(columns=['Sensores', 'MLP', 'MLR', 'KNN', 'RF'])
# rmse_original_dataframe = pd.concat([co_rmse_dataframe, no2_rmse_dataframe, o3_rmse_dataframe, so2_rmse_dataframe], axis=0)
rmse_original_dataframe = o3_rmse_dataframe
rmse_original_dataframe = rmse_original_dataframe.reset_index().drop(columns='index')
rmse_dataframe['Sensores'] = rmse_original_dataframe['Sensores']
mask_dataframe = rmse_original_dataframe.copy()
for index, row in rmse_original_dataframe.iterrows():
    row_MLP = ast.literal_eval(row['MLP'])
    row_MLR = ast.literal_eval(row['MLR'])
    row_KNN = ast.literal_eval(row['KNN'])
    row_RF = ast.literal_eval(row['RF'])
    rmse_dataframe.loc[index, 'MLP'] = f"{round(row_MLP['Mean'], 2)} ± {round(row_MLP['Std'], 2)}"
    rmse_dataframe.loc[index, 'MLR'] = f"{round(row_MLR['Mean'], 2)} ± {round(row_MLR['Std'], 2)}"
    rmse_dataframe.loc[index, 'KNN'] = f"{round(row_KNN['Mean'], 2)} ± {round(row_KNN['Std'], 2)}"
    rmse_dataframe.loc[index, 'RF'] = f"{round(row_RF['Mean'], 2)} ± {round(row_RF['Std'], 2)}"
    
rmse_dataframe.to_csv(output_directory_path + sensor_o3_name + "_rmse_formated_results.csv")
rmse_dataframe
# Out:
#                                               Sensores             MLP  \
# 0                                                 O3 1   -16.72 ± 4.46
# 1                                                 O3 2   -13.77 ± 2.45
# 2                                            CO + O3 1  -25.51 ± 14.52
# 3                                            CO + O3 2     -18.8 ± 5.4
# 4                                           NO2 + O3 1   -17.41 ± 4.53
# ..                                                 ...             ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T  -36.54 ± 26.41
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T    -26.27 ± 9.6
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T   -31.09 ± 5.31
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -29.03 ± 10.51
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T  -30.73 ± 13.66
#
#                MLR            KNN             RF
# 0    -16.15 ± 4.57  -16.92 ± 6.08  -17.59 ± 4.55
# ...

# %% [markdown]
# ### MAE

# %%
import ast

mae_dataframe = pd.DataFrame(columns=['Sensores', 'MLP', 'MLR', 'KNN', 'RF'])
# mae_original_dataframe = pd.concat([co_mae_dataframe, no2_mae_dataframe, o3_mae_dataframe, so2_mae_dataframe], axis=0)
mae_original_dataframe = o3_mae_dataframe
mae_original_dataframe = mae_original_dataframe.reset_index().drop(columns='index')
mae_dataframe['Sensores'] = mae_original_dataframe['Sensores']
mask_dataframe = mae_original_dataframe.copy()
for index, row in mae_original_dataframe.iterrows():
    row_MLP = ast.literal_eval(row['MLP'])
    row_MLR = ast.literal_eval(row['MLR'])
    row_KNN = ast.literal_eval(row['KNN'])
    row_RF = ast.literal_eval(row['RF'])
    mae_dataframe.loc[index, 'MLP'] = f"{round(row_MLP['Mean'], 2)} ± {round(row_MLP['Std'], 2)}"
    mae_dataframe.loc[index, 'MLR'] = f"{round(row_MLR['Mean'], 2)} ± {round(row_MLR['Std'], 2)}"
    mae_dataframe.loc[index, 'KNN'] = f"{round(row_KNN['Mean'], 2)} ± {round(row_KNN['Std'], 2)}"
    mae_dataframe.loc[index, 'RF'] = f"{round(row_RF['Mean'], 2)} ± {round(row_RF['Std'], 2)}"

mae_dataframe.to_csv(output_directory_path + sensor_o3_name + "_mae_formated_results.csv")
mae_dataframe
# Out:
#                                               Sensores             MLP  \
# 0                                                 O3 1   -13.34 ± 2.95
# 1                                                 O3 2    -11.01 ± 2.1
# 2                                            CO + O3 1   -16.47 ± 4.85
# 3                                            CO + O3 2   -14.26 ± 4.51
# 4                                           NO2 + O3 1   -13.19 ± 2.92
# ..                                                 ...             ...
# 187         CO + NO2 + O3 1 + SO2 1 + SO2 2 + PM10 + T  -21.66 ± 12.67
# 188         CO + NO2 + O3 2 + SO2 1 + SO2 2 + PM10 + T   -18.17 ± 6.19
# 189        CO + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T    -20.55 ± 4.1
# 190       NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T    -17.9 ± 2.53
# 191  CO + NO2 + O3 1 + O3 2 + SO2 1 + SO2 2 + PM10 + T   -21.99 ± 9.74
#
#                MLR            KNN             RF
# 0    -12.84 ± 3.18  -12.89 ± 4.47   -14.03 ± 3.2
# ...
